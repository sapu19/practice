# %%
# %cd drive/My Drive/practice/pacman
# Out:
# /content/drive/My Drive/practice/pacman

# %%
# !unzip -q "Ms_Pacman.zip"

# %%
# !pip install chainer

# %%
# !pip install scipy

# %%
# !pip install numpy

# %%
# !pip install cupy-cuda92
# Out:
# ...
#      |████████████████████████████████| 319.6MB 23kB/s
# ...

# %%
# !git clone https://github.com/alokwhitewolf/Video-frame-prediction-by-multi-scale-GAN.git
# Out:
# Cloning into 'Video-frame-prediction-by-multi-scale-GAN'...
# remote: Enumerating objects: 129, done.
# remote: Total 129 (delta 0), reused 0 (delta 0), pack-reused 129
# Receiving objects: 100% (129/129), 2.29 MiB | 4.41 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
# !unzip "Video-frame-prediction-by-multi-scale-GAN-master.zip" -d "/content/drive/My Drive/practice/pacman"
# Out:
# Archive:  Video-frame-prediction-by-multi-scale-GAN-master.zip
# f4c07ac2088e6e0724883353f183474f7b1d13e9
#    creating: /content/drive/My Drive/practice/pacman/Video-frame-prediction-by-multi-scale-GAN-master/
#   inflating: /content/drive/My Drive/practice/pacman/Video-frame-prediction-by-multi-scale-GAN-master/LICENSE
#   inflating: /content/drive/My Drive/practice/pacman/Video-frame-prediction-by-multi-scale-GAN-master/MultiScaleNetwork.py
#   inflating: /content/drive/My Drive/practice/pacman/Video-frame-prediction-by-multi-scale-GAN-master/README.md
#   inflating: /content/drive/My Drive/practice/pacman/Video-frame-prediction-by-multi-scale-GAN-master/constants.py
#   inflating: /content/drive/My Drive/practice/pacman/Video-frame-prediction-by-multi-scale-GAN-master/custom_extensions.py
#   inflating: /content/drive/My Drive/practice/pacman/Video-frame-prediction-by-multi-scale-GAN-master/loader.py
# ...

# %%
pip install 'cupy-cuda92>=6.5.0,<7.0.0'
# Out:
# ...
#      |████████████████████████████████| 333.8MB 51kB/s
# ...
#   Found existing installation: cupy-cuda92 7.2.0
#     Uninstalling cupy-cuda92-7.2.0:
#       Successfully uninstalled cupy-cuda92-7.2.0
# ...

# %%
# !sudo pip install Pillow==2.6.0

# %%
pip install scipy==1.1.0

# %%
pip install cupy --no-cache-dir -vvvv
# Out:
# Created temporary directory: /tmp/pip-ephem-wheel-cache-n39r_ldh
# Created temporary directory: /tmp/pip-req-tracker-7rynv4qg
# Created requirements tracker '/tmp/pip-req-tracker-7rynv4qg'
# Created temporary directory: /tmp/pip-install-dvvtrpf8
# 1 location(s) to search for versions of cupy:
# * https://pypi.org/simple/cupy/
# Getting page https://pypi.org/simple/cupy/
# Found index url https://pypi.org/simple
# Starting new HTTPS connection (1): pypi.org:443
# https://pypi.org:443 "GET /simple/cupy/ HTTP/1.1" 200 5917
# Analyzing links from page https://pypi.org/simple/cupy/
#   Found link https://files.pythonhosted.org/packages/79/e5/c7febd2964bf5e319423045e440ef43ad3aad2dcbe347854e1ad6cc6485a/cupy-1.0.0a1.tar.gz#sha256=4d929ee339ead4709ff809ba2e2544d7f0744d2b8466c9ea7fd803a6c781ac85 (from https://pypi.org/simple/cupy/), version: 1.0.0a1
# ...

# %%
# !python process_data.py -n 500000
# Out:
# num 0f clips  1
# Directory chosen for generating clips:  ['data/Train/0027']
# Image selected for compression:  data/Train/0027/00969.png
# (1, 15, 210, 160)
# Image selected for compression:  data/Train/0027/00970.png
# (1, 15, 210, 160)
# Image selected for compression:  data/Train/0027/00971.png
# (1, 15, 210, 160)
# Image selected for compression:  data/Train/0027/00972.png
# (1, 15, 210, 160)
# Image selected for compression:  data/Train/0027/00973.png
# (1, 15, 210, 160)
# num 0f clips  1
# Directory chosen for generating clips:  ['data/Train/0009']
# Image selected for compression:  data/Train/0009/00994.png
# (1, 15, 210, 160)
# Image selected for compression:  data/Train/0009/00995.png
# (1, 15, 210, 160)
# Image selected for compression:  data/Train/0009/00996.png
# (1, 15, 210, 160)
# Image selected for compression:  data/Train/0009/00997.png
# (1, 15, 210, 160)
# Image selected for compression:  data/Train/0009/00998.png
# (1, 15, 210, 160)
# num 0f clips  1
# ...

# %%
# !python testmodel.py
# Out:
# /usr/local/lib/python3.6/dist-packages/chainer/_environment_check.py:91: UserWarning:
# --------------------------------------------------------------------------------
# Multiple installations of CuPy package has been detected.
# You should select only one package from from ['cupy-cuda101', 'cupy-cuda100', 'cupy-cuda92', 'cupy-cuda91', 'cupy-cuda90', 'cupy-cuda80', 'cupy'].
# Follow these steps to resolve this issue:
#   1. `pip list` to list CuPy packages installed
#   2. `pip uninstall <package name>` to uninstall all CuPy packages
#   3. `pip install <package name>` to install the proper one
# --------------------------------------------------------------------------------
#
#   '''.format(name=name, pkgs=pkgs))
# /usr/local/lib/python3.6/dist-packages/chainer/_environment_check.py:73: UserWarning:
# --------------------------------------------------------------------------------
# CuPy (cupy) version 7.2.0 may not be compatible with this version of Chainer.
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline
# %cd inference
# Out:
# /content/drive/My Drive/practice/pacman/inference

# %%
result=['INPUT0.png','INPUT1.png','INPUT2.png','INPUT3.png','OUTPUTS0.png','OUTPUTS1.png','OUTPUTS2.png','OUTPUTS3.png','OUTPUTS4.png','OUTPUTS5.png','OUTPUTS5.png','OUTPUTS6.png','comparison0.png','comparison1.png','comparison2.png','comparison3.png','comparison4.png','comparison5.png','comparison6.png']
for i in result:
  image = mpimg.imread(i) 
  plt.show()
  plt.imshow(image)
